# %%
import thinkdsp

# %%
class BrownianNoise(_Noise):
    def evaluate(self, ts):
        dys = np.random.uniform(-1, 1, len(ts))
        ys = np.cumsum(dys)
        ys = normalize(unbias(ys), self.amp)
        return ys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d73c3d314e77> in <module>()
# ----> 1 class BrownianNoise(_Noise):
#       2     def evaluate(self, ts):
#       3         dys = np.random.uniform(-1, 1, len(ts))
#       4         ys = np.cumsum(dys)
#       5         ys = normalize(unbias(ys), self.amp)
#
# NameError: name '_Noise' is not defined

# %%
signal = thinkdsp.BrownianNoise()
wave = signal.make_wave(duration=20, framerate=8000)
spectrum = wave.make_spectrum()
result = spectrum.estimate_slope()

# %%
wave.plot()

# %%
spectrum.plot()

# %%
spectrum.high_pass(cutoff=300, factor=0.01)
#wavehi = spectrun.make_wave()
#wavehi.plot()

# %%
spectrum.plot()

# %%
wave = spectrum.make_wave()
wave.write(filename='dsp.wav')
thinkdsp.play_wave(filename='dsp.wave', player = 'aplay')
# Out:
# Writing dsp.wav

# %%
wave.plot()
